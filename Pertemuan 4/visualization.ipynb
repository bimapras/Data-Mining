# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("spek_hp.csv")
data.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0    0.1        193  ...      1412  3476    12     7          2        0
# 1    0.8        191  ...       857  3895     6     0          7        1
# 2    0.9        186  ...      1366  2396    17    10         10        0
# 3    0.5         96  ...      1752  3893    10     0          7        1
# 4    0.5        108  ...       810  1773    15     8          7        1
#
#    touch_screen  wifi  rating  kelayakan
# ...

# %%
data_baru = data.loc[:, ['clock_speed','int_memory','n_cores','ram','rating','kelayakan']]
data_baru
# Out:
#      clock_speed  int_memory  n_cores   ram  rating  kelayakan
# 0            1.8           5        3  3476       4          1
# 1            0.5          61        5  3895       5          1
# 2            2.8          27        3  2396       5          1
# 3            0.5          25        8  3893       5          1
# 4            1.4          49        6  1773       4          1
# ..           ...         ...      ...   ...     ...        ...
# 995          1.9          54        7  2121       5          1
# 996          1.8          13        4  1933       3          0
# 997          1.4           8        1  1223       2          0
# 998          0.5          50        2  2509       4          1
# 999          0.5          35        6  2828       4          1
#
# [1000 rows x 6 columns]

# %%
data_baru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   clock_speed  1000 non-null   float64
#  1   int_memory   1000 non-null   int64
#  2   n_cores      1000 non-null   int64
#  3   ram          1000 non-null   int64
#  4   rating       1000 non-null   int64
#  5   kelayakan    1000 non-null   int64
# dtypes: float64(1), int64(5)
# memory usage: 47.0 KB

# %%
kelayakan_hp = dict(zip(data_baru.rating.unique(), data_baru.kelayakan.unique())) #mengembalikan nilai sesuai dengan argumen yang diberikan
kelayakan_hp
# Out:
# {4: 1, 5: 0}

# %% [markdown]
# # Proses visualiasasi menggunakan 2 diagram berupa diagram lingkaran dan diagram grafik

# %%
s = data_baru['kelayakan'].value_counts()

plt.figure(figsize=(10,10))
plt.pie(s, labels = s.index, autopct=lambda p:f'{p:.2f}%, {p*sum(s)/100 :.0f} units')
plt.title('Sebaran banyaknya handphone yang dapat menggunakan aplikasi berat')
plt.show()

# %%
names = ['kelayakan']

for i in names :
    plt.figure(figsize=(7,4), dpi=90)
    sns.countplot(x=i, data=data_baru, hue= 'rating')
    plt.title('Grafik sebaran handphone yang dapat menggunakan aplikasi berat')
    plt.show()
